# %%
import pandas as pd
import json as j

# %%
table=pd.read_html("https://megaman.fandom.com/wiki/List_of_Mega_Man_Battle_Network_5_Battle_Chips")
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File ~\anaconda3\Lib\urllib\request.py:1344, in AbstractHTTPHandler.do_open(self, http_class, req, **http_conn_args)
#    1343 try:
# -> 1344     h.request(req.get_method(), req.selector, req.data, headers,
#    1345               encode_chunked=req.has_header('Transfer-encoding'))
#    1346 except OSError as err: # timeout error
#
# File ~\anaconda3\Lib\http\client.py:1336, in HTTPConnection.request(self, method, url, body, headers, encode_chunked)
#    1335 """Send a complete request to the server."""
# -> 1336 self._send_request(method, url, body, headers, encode_chunked)
#
# File ~\anaconda3\Lib\http\client.py:1382, in HTTPConnection._send_request(self, method, url, body, headers, encode_chunked)
#    1381     body = _encode(body, 'body')
# -> 1382 self.endheaders(body, encode_chunked=encode_chunked)
#
# ...

# %%
table
# Out:
# [       #  Image                Name  Type Damage Letter Codes  \
#  0      1    NaN       Cannon (キャノン)   NaN     40   A, B, C, *
#  1      2    NaN   HiCannon (ハイキャノン)   NaN     80      D, E, F
#  2      3    NaN   M-Cannon (メガキャノン)   NaN    120      F, G, H
#  3      4    NaN    AirShot (エアシュート)   NaN     20            *
#  4      5    NaN     Vulcan1 (バルカン１)   NaN     10   C, D, E, *
#  ..   ...    ...                 ...   ...    ...          ...
#  175  176    NaN   CopyDmg (コピーダメージ)   NaN      -            *
#  176  177    NaN  LifeSync (ライフシンクロ)   NaN      -   B, R, S, *
#  177  178    NaN  Attck+10 (アタック＋１０)   NaN      -            *
#  178  179    NaN    Navi+20 (ナビー＋２０)   NaN      -            *
#  179  180    NaN   ColorPt (カラーポイント)   NaN      -            *
#
#                         Description  \
#  0         Cannon to attack 1 enemy
#  1         Cannon to attack 1 enemy
#  2         Cannon to attack 1 enemy
#  3         Knock enmy back 1 square
# ...

# %%
table.dropna()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 table.dropna()
#
# AttributeError: 'list' object has no attribute 'dropna'

# %%
table.dropna
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 table.dropna
#
# AttributeError: 'list' object has no attribute 'dropna'

# %%
df=pd.DataFrame(table[0])

# %%
df
# Out:
#        #  Image                Name  Type Damage Letter Codes  \
# 0      1    NaN       Cannon (キャノン)   NaN     40   A, B, C, *
# 1      2    NaN   HiCannon (ハイキャノン)   NaN     80      D, E, F
# 2      3    NaN   M-Cannon (メガキャノン)   NaN    120      F, G, H
# 3      4    NaN    AirShot (エアシュート)   NaN     20            *
# 4      5    NaN     Vulcan1 (バルカン１)   NaN     10   C, D, E, *
# ..   ...    ...                 ...   ...    ...          ...
# 175  176    NaN   CopyDmg (コピーダメージ)   NaN      -            *
# 176  177    NaN  LifeSync (ライフシンクロ)   NaN      -   B, R, S, *
# 177  178    NaN  Attck+10 (アタック＋１０)   NaN      -            *
# 178  179    NaN    Navi+20 (ナビー＋２０)   NaN      -            *
# 179  180    NaN   ColorPt (カラーポイント)   NaN      -            *
#
#                        Description  \
# 0         Cannon to attack 1 enemy
# 1         Cannon to attack 1 enemy
# 2         Cannon to attack 1 enemy
# 3         Knock enmy back 1 square
# 4        3-shot to pierce 1 panel!
# ...

# %%
df.dropna()
# Out:
# Empty DataFrame
# Columns: [#, Image, Name, Type, Damage, Letter Codes, Description, Location]
# Index: []

# %%
df
# Out:
#        #  Image                Name  Type Damage Letter Codes  \
# 0      1    NaN       Cannon (キャノン)   NaN     40   A, B, C, *
# 1      2    NaN   HiCannon (ハイキャノン)   NaN     80      D, E, F
# 2      3    NaN   M-Cannon (メガキャノン)   NaN    120      F, G, H
# 3      4    NaN    AirShot (エアシュート)   NaN     20            *
# 4      5    NaN     Vulcan1 (バルカン１)   NaN     10   C, D, E, *
# ..   ...    ...                 ...   ...    ...          ...
# 175  176    NaN   CopyDmg (コピーダメージ)   NaN      -            *
# 176  177    NaN  LifeSync (ライフシンクロ)   NaN      -   B, R, S, *
# 177  178    NaN  Attck+10 (アタック＋１０)   NaN      -            *
# 178  179    NaN    Navi+20 (ナビー＋２０)   NaN      -            *
# 179  180    NaN   ColorPt (カラーポイント)   NaN      -            *
#
#                        Description  \
# 0         Cannon to attack 1 enemy
# 1         Cannon to attack 1 enemy
# 2         Cannon to attack 1 enemy
# 3         Knock enmy back 1 square
# 4        3-shot to pierce 1 panel!
# ...

# %%
del df["Image"]

# %%
df
# Out:
#        #                Name  Type Damage Letter Codes  \
# 0      1       Cannon (キャノン)   NaN     40   A, B, C, *
# 1      2   HiCannon (ハイキャノン)   NaN     80      D, E, F
# 2      3   M-Cannon (メガキャノン)   NaN    120      F, G, H
# 3      4    AirShot (エアシュート)   NaN     20            *
# 4      5     Vulcan1 (バルカン１)   NaN     10   C, D, E, *
# ..   ...                 ...   ...    ...          ...
# 175  176   CopyDmg (コピーダメージ)   NaN      -            *
# 176  177  LifeSync (ライフシンクロ)   NaN      -   B, R, S, *
# 177  178  Attck+10 (アタック＋１０)   NaN      -            *
# 178  179    Navi+20 (ナビー＋２０)   NaN      -            *
# 179  180   ColorPt (カラーポイント)   NaN      -            *
#
#                        Description  \
# 0         Cannon to attack 1 enemy
# 1         Cannon to attack 1 enemy
# 2         Cannon to attack 1 enemy
# 3         Knock enmy back 1 square
# 4        3-shot to pierce 1 panel!
# ..                             ...
# 175  Duplicate damage to 2nd enemy
# ...

# %%
del df["Type"]

# %%
df
# Out:
#        #                Name Damage Letter Codes  \
# 0      1       Cannon (キャノン)     40   A, B, C, *
# 1      2   HiCannon (ハイキャノン)     80      D, E, F
# 2      3   M-Cannon (メガキャノン)    120      F, G, H
# 3      4    AirShot (エアシュート)     20            *
# 4      5     Vulcan1 (バルカン１)     10   C, D, E, *
# ..   ...                 ...    ...          ...
# 175  176   CopyDmg (コピーダメージ)      -            *
# 176  177  LifeSync (ライフシンクロ)      -   B, R, S, *
# 177  178  Attck+10 (アタック＋１０)      -            *
# 178  179    Navi+20 (ナビー＋２０)      -            *
# 179  180   ColorPt (カラーポイント)      -            *
#
#                        Description  \
# 0         Cannon to attack 1 enemy
# 1         Cannon to attack 1 enemy
# 2         Cannon to attack 1 enemy
# 3         Knock enmy back 1 square
# 4        3-shot to pierce 1 panel!
# ..                             ...
# 175  Duplicate damage to 2nd enemy
# 176         Makes HP same as enemy
# 177   +10 for selected attack Chip
# ...

# %%
df.to_csv("battle_chips.csv")

# %%
table[1]
# Out:
#      # Image                 Name Type   Damage  \
# 0    1   NaN  SuprVulc (スーパーバルカン)  NaN       10
# 1    2   NaN    NeoVari (ネオバリアブル)  NaN      240
# 2    3   NaN    Meteors (リュウセイグン)  NaN       40
# 3    4   NaN    NumbrBl (ナンバーボール)  NaN      ???
# 4    5   NaN    Guardian (オジゾウサン)  NaN      200
# ..  ..   ...                  ...  ...      ...
# 75  35   NaN  KnigtMnSP (ナイトマンＳＰ)  NaN  220~320
# 76  36   NaN  KnigtMnDS (ナイトマンＤＳ)  NaN      ???
# 77  37   NaN      ToadMan (トードマン)  NaN       80
# 78  38   NaN   ToadMnSP (トードマンＳＰ)  NaN  120~220
# 79  39   NaN   ToadMnDS (トードマンＤＳ)  NaN      ???
#
#                       Description  \
# 0           12-shot vulcan cannon
# 1        A magical shifting sword
# 2   Drop many meteor on enmy area
# 3      Last 2 HP digits = atk pwr
# 4        Statue punishes when hit
# ..                            ...
# 75          Circle around and atk
# 76          Circle around and atk
# 77    Sing and paralyze the enemy
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 table
#
# NameError: name 'table' is not defined

# %%
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[47], line 1
# ----> 1 import pillow
#
# ModuleNotFoundError: No module named 'pillow'
