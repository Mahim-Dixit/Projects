# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook
# %matplotlib inline

# %%
tables = pd.read_html("https://megaman.fandom.com/wiki/List_of_Mega_Man_Battle_Network_4_Battle_Chips")

# %%
tables
# Out:
# [                                                   0
#  0  This section of MMKB is under construction. Co...,
#         #  Image      Name  Type Damage Letter Codes Memory  \
#  0      1    NaN    Cannon   NaN     40   A, B, C, *   8 MB
#  1      2    NaN  HiCannon   NaN     80      C, D, E  24 MB
#  2      3    NaN  M-Cannon   NaN    120      E, F, G  40 MB
#  3      4    NaN   AirShot   NaN     20   A, S, V, *   6 MB
#  4      5    NaN   Vulcan1   NaN     10   E, S, V, *   6 MB
#  ..   ...    ...       ...   ...    ...          ...    ...
#  145  146    NaN   CopyDmg   NaN      -            *  12 MB
#  146  147    NaN  LifeSync   NaN      -      N, Q, Y  12 MB
#  147  148    NaN    Atk+10   NaN      -            *   6 MB
#  148  149    NaN   Navi+20   NaN      -            *  36 MB
#  149  150    NaN   ColorPt   NaN      -            *  25 MB
#
#                         Description  \
#  0         Cannon to attack 1 enemy
#  1         Cannon to attack 1 enemy
# ...

# %%
for i in range(len(tables)):
    df=pd.DataFrame(tables[i])
    df.to_csv(f"chip_data{i}.csv")
